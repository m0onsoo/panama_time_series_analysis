# %%
import pandas as pd

# %%
df = pd.read_csv("Gatun_Lake_Water_Level_Monthly_Mean.csv")

# %%
df.set_index('DATE_LOG', inplace=True)
df.index = pd.to_datetime(df.index)
df
# Out:
#             GATUN_LAKE_LEVEL(FEET)
# DATE_LOG
# 1965-01-31               86.363548
# 1965-02-28               85.753571
# 1965-03-31               84.521935
# 1965-04-30               83.380667
# 1965-05-31               82.677742
# ...                            ...
# 2024-01-31               81.437742
# 2024-02-29               80.986207
# 2024-03-31               80.518065
# 2024-04-30               80.302000
# 2024-05-31               80.551500
#
# [701 rows x 1 columns]

# %%
df['GATUN_LAKE_LEVEL(FEET)'].mean()
# Out:
# 85.33183993574892

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
plt.figure(figsize=(25, 8))
sns.lineplot(df[df.index >= '2010-01-01'])
# plt.plot(df[df.index >= '2015-01-01'])
# plt.xticks(df[df.index >= '2010-01-01'].index, rotation=45)
plt.ylim([75, 95])
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('ggplot')
plt.figure(figsize=(20, 8))
sns.lineplot(df[df.index >= '2020-01-01'])
# plt.plot(df[df.index >= '2015-01-01'])
# plt.xticks(df[df.index >= '2010-01-01'].index, rotation=45)
plt.ylim([75, 95])
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Generating a sample dataframe
# date_range = pd.date_range(start='2010-01-01', end='2024-05-01', freq='M')


# Creating the lineplot
plt.figure(figsize=(20, 8))
# sns.lineplot(df[df.index >= '2010-01-01'])

df2 = df[df.index >= '2020-01-01']
sns.lineplot(data=df2, x=df2.index, y='GATUN_LAKE_LEVEL(FEET)')
plt.xticks(rotation=45)
plt.gca().xaxis.set_major_locator(plt.MaxNLocator(10))  # Ensure one tick per year approximately
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y'))  # Format x-axis ticks as year

plt.ylim([75, 95])
plt.xlabel('Year')
plt.ylabel('Value')
plt.title('Sample Lineplot with Yearly X-axis Labels Rotated 45 Degrees')
plt.tight_layout()
plt.show()
